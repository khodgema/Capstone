# %%
import pandas as pd
import numpy as np
import os
import glob
import shap
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import xgboost as xgb

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.preprocessing import RobustScaler
import matplotlib.cm as cm
from sklearn.metrics import silhouette_samples, silhouette_score, pairwise_distances
from sklearn import metrics
#from google.colab import drive

# %%
df = pd.read_csv('2013-24_model_input_rolling_cluster.csv')

# %%
specific_game_rows = df[df['GAME_ID'] == 21300023]

# Display the filtered rows
print(specific_game_rows)
# Out:
#       SEASON_YEAR     TEAM_ID   GAME_ID  WL  HOME_AWAY  win_percentage  \
# 0         2013-14  1610612737  21300023   1          1             0.0
# 20821     2013-14  1610612761  21300023   0          0             1.0
#
#        FGM_rolling  FGA_rolling  FG_PCT_rolling  FG3M_rolling  ...  cluster_4  \
# 0             37.0         76.0           0.487           8.0  ...   0.056125
# 20821         38.0         86.0           0.442           5.0  ...   0.000000
#
#        cluster_5  cluster_6  cluster_7  cluster_8  cluster_9  cluster_10  \
# 0            0.0   0.026625   0.020875        0.0   0.063375         0.0
# 20821        0.0   0.000000   0.013167        0.0   0.028667         0.0
#
#        cluster_11  cluster_12  cluster_13
# 0             0.0         0.0    0.049125
# 20821         0.0         0.0    0.116500
#
# [2 rows x 60 columns]

# %%
# Identify the rolling stats columns
rolling_stats = [col for col in df.columns if col.endswith('_rolling')]

# Create opponent columns and compute the difference for each rolling stat
for stat in rolling_stats:
    # Shift to get opponent's stats
    df[f'opp_{stat}'] = df.groupby('GAME_ID')[stat].shift(-1)
    df[f'diff_{stat}'] = df[stat] - df[f'opp_{stat}']

# For the second team (reverse the shift), fill in the NaN values
for stat in rolling_stats:
    df[f'opp_{stat}'] = df.groupby('GAME_ID')[f'opp_{stat}'].fillna(df.groupby('GAME_ID')[stat].shift(1))
    df[f'diff_{stat}'] = df[stat] - df[f'opp_{stat}']  # Difference between team's and opponent's rolling stats

# Check if there are still NaN values
print(df.isnull().sum())
# Out:
# SEASON_YEAR                0
# TEAM_ID                    0
# GAME_ID                    0
# WL                         0
# HOME_AWAY                  0
#                           ..
# diff_PACE_PER40_rolling    0
# opp_POSS_rolling           0
# diff_POSS_rolling          0
# opp_PIE_rolling            0
# diff_PIE_rolling           0
# Length: 140, dtype: int64

# %%
df.head()
# Out:
#   SEASON_YEAR     TEAM_ID   GAME_ID  WL  HOME_AWAY  win_percentage  \
# 0     2013-14  1610612737  21300023   1          1        0.000000
# 1     2013-14  1610612737  21300046   0          0        0.500000
# 2     2013-14  1610612737  21300059   1          0        0.333333
# 3     2013-14  1610612737  21300071   0          0        0.500000
# 4     2013-14  1610612737  21300086   1          1        0.400000
#
#    FGM_rolling  FGA_rolling  FG_PCT_rolling  FG3M_rolling  ...  \
# 0    37.000000         76.0        0.487000          8.00  ...
# 1    36.500000         76.5        0.477500          9.00  ...
# 2    37.666667         81.0        0.466333          9.00  ...
# 3    38.000000         81.0        0.470000          8.75  ...
# 4    39.500000         85.5        0.462500          8.75  ...
#
#    opp_E_PACE_rolling  diff_E_PACE_rolling  opp_PACE_rolling  \
# 0           94.440000             7.540000         92.000000
# 1          102.086667            -2.896667         99.333333
# 2           94.246667             7.046667         92.500000
# 3           99.793333             0.511667         97.500000
# 4           98.690000             1.100000         96.750000
#
#    diff_PACE_rolling  opp_PACE_PER40_rolling  diff_PACE_PER40_rolling  \
# 0          11.500000               76.670000                 9.580000
# 1          -0.083333               82.776667                -0.066667
# 2           8.833333               77.083333                 7.363333
# 3           2.625000               81.250000                 2.190000
# 4           1.875000               80.625000                 1.565000
#
#    opp_POSS_rolling  diff_POSS_rolling  opp_PIE_rolling  diff_PIE_rolling
# 0         92.000000          12.000000         0.516000         -0.049000
# 1         99.333333           0.166667         0.426667          0.100333
# 2         92.333333           9.333333         0.424333          0.085667
# 3         97.333333           2.916667         0.447333          0.074917
# 4         96.500000           2.250000         0.588500         -0.057500
#
# [5 rows x 140 columns]

# %%
columns_to_keep = ['SEASON_YEAR', 'TEAM_ID', 'GAME_ID', 'WL', 'HOME_AWAY', 'win_percentage'] + [col for col in df.columns if col.startswith('diff_') and col.endswith('_rolling')]
df_model = df[columns_to_keep]

print(df_model.head())
# Out:
#   SEASON_YEAR     TEAM_ID   GAME_ID  WL  HOME_AWAY  win_percentage  \
# 0     2013-14  1610612737  21300023   1          1        0.000000
# 1     2013-14  1610612737  21300046   0          0        0.500000
# 2     2013-14  1610612737  21300059   1          0        0.333333
# 3     2013-14  1610612737  21300071   0          0        0.500000
# 4     2013-14  1610612737  21300086   1          1        0.400000
#
#    diff_FGM_rolling  diff_FGA_rolling  diff_FG_PCT_rolling  diff_FG3M_rolling  \
# 0         -1.000000        -10.000000             0.045000           3.000000
# 1          0.833333        -11.500000             0.073833          -1.000000
# 2          4.666667         -1.333333             0.063667           2.333333
# 3          3.000000         -6.000000             0.064667           2.083333
# 4          1.000000          4.500000            -0.016250           2.000000
#
#    ...  diff_E_TM_TOV_PCT_rolling  diff_TM_TOV_PCT_rolling  \
# 0  ...                  -2.482000                -3.300000
# 1  ...                  -0.487167                -1.033333
# 2  ...                   0.396000                 0.100000
# 3  ...                  -1.320000                -1.741667
# 4  ...                  -4.730750                -4.975000
#
#    diff_EFG_PCT_rolling  diff_TS_PCT_rolling  diff_E_USG_PCT_rolling  \
# 0              0.068000             0.112000                0.001000
# 1              0.075500             0.083500                0.003000
# 2              0.078333             0.061333                0.002000
# 3              0.080000             0.075083                0.000667
# 4             -0.007500            -0.016250               -0.001000
#
#    diff_E_PACE_rolling  diff_PACE_rolling  diff_PACE_PER40_rolling  \
# 0             7.540000          11.500000                 9.580000
# 1            -2.896667          -0.083333                -0.066667
# 2             7.046667           8.833333                 7.363333
# 3             0.511667           2.625000                 2.190000
# 4             1.100000           1.875000                 1.565000
#
#    diff_POSS_rolling  diff_PIE_rolling
# 0          12.000000         -0.049000
# 1           0.166667          0.100333
# 2           9.333333          0.085667
# 3           2.916667          0.074917
# 4           2.250000         -0.057500
#
# [5 rows x 46 columns]

# %%
# Filter rows where TEAM_ID is 1610612737
specific_game_rows = df_model[df_model['GAME_ID'] == 21300023]

# Display the filtered rows
print(specific_game_rows)
# Out:
#       SEASON_YEAR     TEAM_ID   GAME_ID  WL  HOME_AWAY  win_percentage  \
# 0         2013-14  1610612737  21300023   1          1             0.0
# 20821     2013-14  1610612761  21300023   0          0             1.0
#
#        diff_FGM_rolling  diff_FGA_rolling  diff_FG_PCT_rolling  \
# 0                  -1.0             -10.0                0.045
# 20821               1.0              10.0               -0.045
#
#        diff_FG3M_rolling  ...  diff_E_TM_TOV_PCT_rolling  \
# 0                    3.0  ...                     -2.482
# 20821               -3.0  ...                      2.482
#
#        diff_TM_TOV_PCT_rolling  diff_EFG_PCT_rolling  diff_TS_PCT_rolling  \
# 0                         -3.3                 0.068                0.112
# 20821                      3.3                -0.068               -0.112
#
#        diff_E_USG_PCT_rolling  diff_E_PACE_rolling  diff_PACE_rolling  \
# 0                       0.001                 7.54               11.5
# 20821                  -0.001                -7.54              -11.5
#
#        diff_PACE_PER40_rolling  diff_POSS_rolling  diff_PIE_rolling
# 0                         9.58               12.0            -0.049
# 20821                    -9.58              -12.0             0.049
#
# [2 rows x 46 columns]

# %%
list(df_model.columns)
# Out:
# ['SEASON_YEAR',
#  'TEAM_ID',
#  'GAME_ID',
#  'WL',
#  'HOME_AWAY',
#  'win_percentage',
#  'diff_FGM_rolling',
#  'diff_FGA_rolling',
#  'diff_FG_PCT_rolling',
#  'diff_FG3M_rolling',
#  'diff_FG3A_rolling',
#  'diff_FG3_PCT_rolling',
#  'diff_FTM_rolling',
#  'diff_FTA_rolling',
#  'diff_FT_PCT_rolling',
#  'diff_OREB_rolling',
#  'diff_DREB_rolling',
#  'diff_REB_rolling',
#  'diff_AST_rolling',
#  'diff_TOV_rolling',
#  'diff_STL_rolling',
#  'diff_BLK_rolling',
#  'diff_BLKA_rolling',
#  'diff_PF_rolling',
#  'diff_PFD_rolling',
#  'diff_PTS_rolling',
#  'diff_PLUS_MINUS_rolling',
#  'diff_E_OFF_RATING_rolling',
#  'diff_OFF_RATING_rolling',
#  'diff_E_DEF_RATING_rolling',
#  'diff_DEF_RATING_rolling',
#  'diff_E_NET_RATING_rolling',
#  'diff_NET_RATING_rolling',
#  'diff_AST_PCT_rolling',
#  'diff_AST_TOV_rolling',
#  'diff_AST_RATIO_rolling',
#  'diff_E_TM_TOV_PCT_rolling',
#  'diff_TM_TOV_PCT_rolling',
#  'diff_EFG_PCT_rolling',
#  'diff_TS_PCT_rolling',
#  'diff_E_USG_PCT_rolling',
#  'diff_E_PACE_rolling',
#  'diff_PACE_rolling',
#  'diff_PACE_PER40_rolling',
#  'diff_POSS_rolling',
#  'diff_PIE_rolling']

# %%
null_counts = df_model.isnull().sum()
print(null_counts[null_counts > 0])
# Out:
# Series([], dtype: int64)

# %%
# final two seasons for the test set
df_test = df_model[df_model['SEASON_YEAR'].isin(['2022-23', '2023-24'])]

# remaining seasons for training and validation
df_train_val = df_model[~df_model['SEASON_YEAR'].isin(['2022-23', '2023-24'])]

X_train_val = df_train_val.drop(columns=['SEASON_YEAR', 'WL'])
y_train_val = df_train_val['WL']

X_test = df_test.drop(columns=['SEASON_YEAR', 'WL'])
y_test = df_test['WL']

# 80/20 split for training and val
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.2, random_state=42, stratify=y_train_val)

print(f"Training set shape: {X_train.shape}")
print(f"Validation set shape: {X_val.shape}")
print(f"Test set shape: {X_test.shape}")
# Out:
# Training set shape: (16932, 44)
# Validation set shape: (4234, 44)
# Test set shape: (4858, 44)

# %%
X_train_identifiers = X_train[['TEAM_ID', 'GAME_ID']]
X_val_identifiers = X_val[['TEAM_ID', 'GAME_ID']]
X_test_identifiers = X_test[['TEAM_ID', 'GAME_ID']]

X_train = X_train.drop(columns=['TEAM_ID', 'GAME_ID'])
X_val = X_val.drop(columns=['TEAM_ID', 'GAME_ID'])
X_test = X_test.drop(columns=['TEAM_ID', 'GAME_ID'])

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_train_scaled = scaler.fit_transform(X_train) 
X_val_scaled = scaler.transform(X_val)  
X_test_scaled = scaler.transform(X_test)

X_train_scaled_df = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_val_scaled_df = pd.DataFrame(X_val_scaled, columns=X_val.columns)
X_test_scaled_df = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(X_train_scaled_df['diff_PTS_rolling'], kde=True, color='blue')
plt.title('Distribution of PTS_rolling Diff After Robust Scaling')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(X_train_scaled_df['diff_OFF_RATING_rolling'], kde=True, color='blue')
plt.title('Distribution of OFF_RATING_rolling diff After Robust Scaling')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# # Model
# ## Logistic Regression

# %%
log_reg = LogisticRegression(max_iter=1000, random_state=42)

log_reg.fit(X_train_scaled_df, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
y_val_pred = log_reg.predict(X_val_scaled_df)

val_accuracy = accuracy_score(y_val, y_val_pred)
print(f"Validation Accuracy: {val_accuracy:.4f}")

print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))

print("Classification Report:")
print(classification_report(y_val, y_val_pred))
# Out:
# Validation Accuracy: 0.6368
# Confusion Matrix:
# [[1346  771]
#  [ 767 1350]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64      2117
#            1       0.64      0.64      0.64      2117
#
#     accuracy                           0.64      4234
#    macro avg       0.64      0.64      0.64      4234
# weighted avg       0.64      0.64      0.64      4234

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(random_state=42)

param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'penalty': ['l1', 'l2', 'elasticnet'],
    'solver': ['liblinear', 'saga'],
    'max_iter': [100, 500, 1000]
}

grid_search = GridSearchCV(log_reg, param_grid, cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

grid_search.fit(X_train_scaled_df, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Validation Accuracy:", grid_search.best_score_)

best_log_reg = grid_search.best_estimator_
y_val_pred = best_log_reg.predict(X_val_scaled_df)

from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_val, y_val_pred))
print(classification_report(y_val, y_val_pred))
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 150 fits failed out of a total of 450.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 64, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 75 fits failed with the following error:
# Traceback (most recent call last):
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1291, in fit
#     fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 521, in _logistic_regression_path
#     alpha = (1.0 / C) * (1 - l1_ratio)
#                          ~~^~~~~~~~~~
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.6212503  0.62107303 0.62420303 0.62491178        nan        nan
#  0.6212503  0.62095481 0.62420303 0.62497079        nan        nan
#  0.6212503  0.62077765 0.62420303 0.62497079        nan        nan
#  0.62556141 0.62461672 0.624203   0.62585702        nan        nan
#  0.62556141 0.62503007 0.624203   0.62508882        nan        nan
#  0.62556141 0.62526618 0.624203   0.62426204        nan        nan
#  0.62308095 0.62573882 0.62319905 0.62603415        nan        nan
#  0.62308095 0.62467541 0.62319905 0.62508879        nan        nan
#  0.62308095 0.62449831 0.62319905 0.62373051        nan        nan
#  0.62266761 0.62585697 0.62278573 0.62615225        nan        nan
#  0.62266761 0.62508879 0.62278573 0.62502976        nan        nan
#  0.62266761 0.62361238 0.62278573 0.62384865        nan        nan
#  0.62260856 0.62609318 0.62349449 0.62609318        nan        nan
#  0.62260856 0.62502976 0.62349449 0.62497071        nan        nan
#  0.62260856 0.62384865 0.62349449 0.62384865        nan        nan]
#   warnings.warn(
# Best Parameters: {'C': 10, 'max_iter': 100, 'penalty': 'l2', 'solver': 'saga'}
# Best Validation Accuracy: 0.626152250596466
# [[1347  770]
#  [ 768 1349]]
#               precision    recall  f1-score   support
#
#            0       0.64      0.64      0.64      2117
#            1       0.64      0.64      0.64      2117
#
#     accuracy                           0.64      4234
#    macro avg       0.64      0.64      0.64      4234
# weighted avg       0.64      0.64      0.64      4234
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# ## XGBoost

# %%
import xgboost as xgb

# convert the dataset into DMatrix (optimized for XGBoost) - 
dtrain = xgb.DMatrix(X_train_scaled_df, label=y_train)
dval = xgb.DMatrix(X_val_scaled_df, label=y_val)

params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss', 
    'eta': 0.1,  # learning rate
    'max_depth': 5, 
    'subsample': 0.8, 
    'colsample_bytree': 0.8 
}

evals = [(dtrain, 'train'), (dval, 'eval')]
xgb_model = xgb.train(params, dtrain, num_boost_round=100, early_stopping_rounds=10, evals=evals)

y_val_pred = (xgb_model.predict(dval) > 0.5).astype(int)

print("Validation Accuracy:", accuracy_score(y_val, y_val_pred))
print(confusion_matrix(y_val, y_val_pred))
print(classification_report(y_val, y_val_pred))
# Out:
# [0]	train-logloss:0.68493	eval-logloss:0.68642
# [1]	train-logloss:0.67806	eval-logloss:0.68064
# [2]	train-logloss:0.67070	eval-logloss:0.67478
# [3]	train-logloss:0.66558	eval-logloss:0.67107
# [4]	train-logloss:0.65981	eval-logloss:0.66600
# [5]	train-logloss:0.65487	eval-logloss:0.66245
# [6]	train-logloss:0.65105	eval-logloss:0.65955
# [7]	train-logloss:0.64768	eval-logloss:0.65751
# [8]	train-logloss:0.64436	eval-logloss:0.65518
# [9]	train-logloss:0.64145	eval-logloss:0.65330
# [10]	train-logloss:0.63882	eval-logloss:0.65169
# [11]	train-logloss:0.63661	eval-logloss:0.65079
# [12]	train-logloss:0.63412	eval-logloss:0.64909
# [13]	train-logloss:0.63205	eval-logloss:0.64829
# [14]	train-logloss:0.62995	eval-logloss:0.64736
# [15]	train-logloss:0.62792	eval-logloss:0.64690
# [16]	train-logloss:0.62617	eval-logloss:0.64621
# [17]	train-logloss:0.62464	eval-logloss:0.64594
# [18]	train-logloss:0.62319	eval-logloss:0.64541
# [19]	train-logloss:0.62156	eval-logloss:0.64487
# [20]	train-logloss:0.62016	eval-logloss:0.64446
# [21]	train-logloss:0.61890	eval-logloss:0.64390
# [22]	train-logloss:0.61766	eval-logloss:0.64355
# [23]	train-logloss:0.61656	eval-logloss:0.64348
# [24]	train-logloss:0.61528	eval-logloss:0.64317
# [25]	train-logloss:0.61431	eval-logloss:0.64309
# [26]	train-logloss:0.61310	eval-logloss:0.64274
# [27]	train-logloss:0.61197	eval-logloss:0.64261
# [28]	train-logloss:0.61091	eval-logloss:0.64285
# [29]	train-logloss:0.60974	eval-logloss:0.64310
# [30]	train-logloss:0.60845	eval-logloss:0.64305
# [31]	train-logloss:0.60739	eval-logloss:0.64277
# [32]	train-logloss:0.60625	eval-logloss:0.64314
# [33]	train-logloss:0.60550	eval-logloss:0.64329
# [34]	train-logloss:0.60456	eval-logloss:0.64322
# [35]	train-logloss:0.60353	eval-logloss:0.64346
# [36]	train-logloss:0.60311	eval-logloss:0.64340
# Validation Accuracy: 0.6306093528578177
# [[1332  785]
#  [ 779 1338]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.63      0.63      2117
#            1       0.63      0.63      0.63      2117
#
#     accuracy                           0.63      4234
#    macro avg       0.63      0.63      0.63      4234
# weighted avg       0.63      0.63      0.63      4234

# %%
from sklearn.model_selection import GridSearchCV

param_grid = {
    'max_depth': [3, 5, 7],
    'learning_rate': [0.01, 0.1, 0.3],
    'n_estimators': [100, 200, 300],
    'subsample': [0.7, 0.8, 1],
    'colsample_bytree': [0.7, 0.8, 1]
}

xgb_clf = xgb.XGBClassifier()
grid_search = GridSearchCV(xgb_clf, param_grid, cv=3, scoring='accuracy', n_jobs=-1)
grid_search.fit(X_train_scaled_df, y_train)

print("Best Parameters:", grid_search.best_params_)
print("Best Validation Accuracy:", grid_search.best_score_)
# Out:
# Best Parameters: {'colsample_bytree': 0.7, 'learning_rate': 0.01, 'max_depth': 5, 'n_estimators': 300, 'subsample': 0.8}
# Best Validation Accuracy: 0.6298724309000708

# %% [markdown]
# ## SVC

# %%
from sklearn.svm import SVC

# train SVM
svm_model = SVC(kernel='rbf', C=1.0, gamma='scale', probability=True)
svm_model.fit(X_train_scaled_df, y_train)

y_val_pred_svm = svm_model.predict(X_val_scaled_df)

print("Validation Accuracy:", accuracy_score(y_val, y_val_pred_svm))
print(confusion_matrix(y_val, y_val_pred_svm))
print(classification_report(y_val, y_val_pred_svm))
# Out:
# Validation Accuracy: 0.6280113367973548
# [[1309  808]
#  [ 767 1350]]
#               precision    recall  f1-score   support
#
#            0       0.63      0.62      0.62      2117
#            1       0.63      0.64      0.63      2117
#
#     accuracy                           0.63      4234
#    macro avg       0.63      0.63      0.63      4234
# weighted avg       0.63      0.63      0.63      4234

# %%
param_grid_svm = {
    'C': [0.1, 1, 10],
    'gamma': ['scale', 0.01, 0.1, 1],
    'kernel': ['linear', 'rbf']
}

grid_search_svm = GridSearchCV(SVC(probability=True), param_grid_svm, cv=3, scoring='accuracy', n_jobs=-1)
grid_search_svm.fit(X_train_scaled_df, y_train)

print("Best Parameters SVM:", grid_search_svm.best_params_)
print("Best Validation Accuracy SVM:", grid_search_svm.best_score_)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:700: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# Best Parameters SVM: {'C': 10, 'gamma': 'scale', 'kernel': 'linear'}
# Best Validation Accuracy SVM: 0.6262107252539569

# %% [markdown]
# ## Playing with SHAP

# %%
import shap

# load the JS visualization for Jupyter
shap.initjs()

# explainer for predictions of XGBoost model
explainer = shap.Explainer(xgb_model)
shap_values = explainer.shap_values(X_val_scaled_df)

# viz the SHAP values for first prediction
shap.force_plot(explainer.expected_value, shap_values[0,:], X_val_scaled_df.iloc[0,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e={486:function(e,t,n){var r;e=n.nmd(e),function(){var a,i="Expected a function",o="__lodash_hash_undefined__",u="__lodash_placeholder__",l=32,s=128,c=1/0,f=9007199254740991,p=NaN,d=4294967295,h=[["ary",s],["bind",1],["bindKey",2],["curry",8],["curryRight",16],["flip",512],["partial",l],["partialRight",64],["rearg",256]],v="[object Arguments]",g="[object Array]",y="[object Boolean]",m="[object Date]",b="[object Error]",_="[object Function]",w="[object GeneratorFunction]",x="[object Map]",k="[object Number]",S="[object Object]",E="[object Promise]",C="[object RegExp]",T="[object Set]",M="[object String]",N="[object Symbol]",P="[object WeakMap]",z="[object ArrayBuffer]",L="[object DataView]",O="[object Float32Array]",A="[object Float64Array]",F="[object Int8Array]",D="[object Int16Array]",R="[object Int32Array]",j="[object Uint8Array]",U="[object Uint8ClampedArray]",I="[object Uint16Array]",$="[object Uint32Array]",B=/\b__p \+= '';/g,W=/\b(__p \+=) '' \+/g,V=/(__e\(.*?\)|\b__t\)) \+\n'';/g,H=/&(?:amp|lt|gt|quot|#39);/g,q=/[&<>"']/g,Q=RegExp(H.source),Y=RegExp(q.source),G=/<%-([\s\S]+?)%>/g,K=/<%([\s\S]+?)%>/g,Z=/<%=([\s\S]+?)%>/g,X=/\.|\[(?:[^[\]]*|(["'])(?:(?!\1)[^\\]|\\.)*?\1)\]/,J=/^\w*$/,ee=/[^.[\]]+|\[(?:(-?\d+(?:\.\d+)?)|(["'])((?:(?!\2)[^\\]|\\.)*?)\2)\]|(?=(?:\.|\[\])(?:\.|\[\]|$))/g,te=/[\\^$.*+?()[\]{}|]/g,ne=RegExp(te.source),re=/^\s+/,ae=/\s/,ie=/\{(?:\n\/\* \[wrapped with .+\] \*\/)?\n?/,oe=/\{\n\/\* \[wrapped with (.+)\] \*/,ue=/,? & /,le=/[^\x00-\x2f\x3a-\x40\x5b-\x60\x7b-\x7f]+/g,se=/[()=,{}\[\]\/\s]/,ce=/\\(\\)?/g,fe=/\$\{([^\\}]*(?:\\.[^\\}]*)*)\}/g,pe=/\w*$/,de=/^[-+]0x[0-9a-f]+$/i,he=/^0b[01]+$/i,ve=/^\[object .+?Constructor\]$/,ge=/^0o[0-7]+$/i,ye=/^(?:0|[1-9]\d*)$/,me=/[\xc0-\xd6\xd8-\xf6\xf8-\xff\u0100-\u017f]/g,be=/($^)/,_e=/['\n\r\u2028\u2029\\]/g,we="\\ud800-\\udfff",xe="\\u0300-\\u036f\\ufe20-\\ufe2f\\u20d0-\\u20ff",ke="\\u2700-\\u27bf",Se="a-z\\xdf-\\xf6\\xf8-\\xff",Ee="A-Z\\xc0-\\xd6\\xd8-\\xde",Ce="\\ufe0e\\ufe0f",Te="\\xac\\xb1\\xd7\\xf7\\x00-\\x2f\\x3a-\\x40\\x5b-\\x60\\x7b-\\xbf\\u2000-\\u206f \\t\\x0b\\f\\xa0\\ufeff\\n\\r\\u2028\\u2029\\u1680\\u180e\\u2000\\u2001\\u2002\\u2003\\u2004\\u2005\\u2006\\u2007\\u2008\\u2009\\u200a\\u202f\\u205f\\u3000",Me="["+we+"]",Ne="["+Te+"]",Pe="["+xe+"]",ze="\\d+",Le="["+ke+"]",Oe="["+Se+"]",Ae="[^"+we+Te+ze+ke+Se+Ee+"]",Fe="\\ud83c[\\udffb-\\udfff]",De="[^"+we+"]",Re="(?:\\ud83c[\\udde6-\\uddff]){2}",je="[\\ud800-\\udbff][\\udc00-\\udfff]",Ue="["+Ee+"]",Ie="\\u200d",$e="(?:"+Oe+"|"+Ae+")",Be="(?:"+Ue+"|"+Ae+")",We="(?:['’](?:d|ll|m|re|s|t|ve))?",Ve="(?:['’](?:D|LL|M|RE|S|T|VE))?",He="(?:"+Pe+"|"+Fe+")?",qe="["+Ce+"]?",Qe=qe+He+"(?:"+Ie+"(?:"+[De,Re,je].join("|")+")"+qe+He+")*",Ye="(?:"+[Le,Re,je].join("|")+")"+Qe,Ge="(?:"+[De+Pe+"?",Pe,Re,je,Me].join("|")+")",Ke=RegExp("['’]","g"),Ze=RegExp(Pe,"g"),Xe=RegExp(Fe+"(?="+Fe+")|"+Ge+Qe,"g"),Je=RegExp([Ue+"?"+Oe+"+"+We+"(?="+[Ne,Ue,"$"].join("|")+")",Be+"+"+Ve+"(?="+[Ne,Ue+$e,"$"].join("|")+")",Ue+"?"+$e+"+"+We,Ue+"+"+Ve,"\\d*(?:1ST|2ND|3RD|(?![123])\\dTH)(?=\\b|[a-z_])","\\d*(?:1st|2nd|3rd|(?![123])\\dth)(?=\\b|[A-Z_])",ze,Ye].join("|"),"g"),et=RegExp("["+Ie+we+xe+Ce+"]"),tt=/[a-z][A-Z]|[A-Z]{2}[a-z]|[0-9][a-zA-Z]|[a-zA-Z][0-9]|[^a-zA-Z0-9 ]/,nt=["Array","Buffer","DataView","Date","Error","Float32Array","Float64Array","Function","Int8Array","Int16Array","Int32Array","Map","Math","Object","Promise","RegExp","Set","String","Symbol","TypeError","Uint8Array","Uint8ClampedArray","Uint16Array","Uint32Array","WeakMap","_","clearTimeout","isFinite","parseInt","setTimeout"],rt=-1,at={};at[O]=at[A]=at[F]=at[D]=at[R]=at[j]=at[U]=at[I]=at[$]=!0,at[v]=at[g]=at[z]=at[y]=at[L]=at[m]=at[b]=at[_]=at[x]=at[k]=at[S]=at[C]=at[T]=at[M]=at[P]=!1;var it={};it[v]=it[g]=it[z]=it[L]=it[y]=it[m]=it[O]=it[A]=it[F]=it[D]=it[R]=it[x]=it[k]=it[S]=it[C]=it[T]=it[M]=it[N]=it[j]=it[U]=it[I]=it[$]=!0,it[b]=it[_]=it[P]=!1;var ot={"\\":"\\","'":"'","\n":"n","\r":"r","\u2028":"u2028","\u2029":"u2029"},ut=parseFloat,lt=parseInt,st="object"==typ ...
# <div id='i4V4CNBTO0NCHB928XXN6'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.0004082362574990839, "outValue": -0.3902684450149536, "link": "identity", "featureNames": ["HOME_AWAY", "win_percentage", "diff_FGM_rolling", "diff_FGA_rolling", "diff_FG_PCT_rolling", "diff_FG3M_rolling", "diff_FG3A_rolling", "diff_FG3_PCT_rolling", "diff_FTM_rolling", "diff_FTA_rolling", "diff_FT_PCT_rolling", "diff_OREB_rolling", "diff_DREB_rolling", "diff_REB_rolling", "diff_AST_rolling", "diff_TOV_rolling", "diff_STL_rolling", "diff_BLK_rolling", "diff_BLKA_rolling", "diff_PF_rolling", "diff_PFD_rolling", "diff_PTS_rolling", "diff_PLUS_MINUS_rolling", "diff_E_OFF_RATING_rolling", "diff_OFF_RATING_rolling", "diff_E_DEF_RATING_rolling", "diff_DEF_RATING_rolling", "diff_E_NET_RATING_rolling", "diff_NET_RATING_rolling", "diff_AST_PCT_rolling", "diff_AST_TOV_rolling", "diff_AST_RATIO_rolling", "diff_E_TM_TOV_PCT_rolling", "diff_TM_TOV_PCT_rolling", "diff_EFG_PCT_rolling", "diff_TS_PCT_rolling", "diff_E_USG_PCT_rolling", "diff_E_PACE_rolling", "diff_PACE_rolling", "diff_PACE_PER40_rolling", "diff_POSS_rolling", "diff_PIE_rolling"], "features": {"0": {"effect": 0.24490021169185638, "value": 1.0}, "1": {"effect": -0.26867640018463135, "value": -0.19009816582197717}, "2": {"effect": 0.0010671071941033006, "value": -0.8181818181818182}, "3": {"effect": 0.01051219180226326, "value": -1.2333333333333334}, "4": {"effect": -0.0064092171378433704, "value": -0.05907172995780687}, "5": {"effect": 0.013204666785895824, "value": -0.2777777777777778}, "6": {"effect": -0.0039317552000284195, "value": -0.34210526315789475}, "7": {"effect": 0.007775241509079933, "value": -0.15702479338842967}, "8": {"effect": -0.0027439319528639317, "value": 0.5}, "9": {"effect": -0.000889448681846261, "value": 0.46875}, "10": {"effect": -5.305853846948594e-05, "value": 0.07077625570776089}, "11": {"effect": -0.0012430319329723716, "value": -0.625}, "12": {"effect": 0.011585885658860207, "value": 0.5217391304347826}, "13": {"effect": -0.0022656917572021484, "value": 0.07142857142857142}, "14": {"effect": 0.0013761058216914535, "value": 0.375}, "15": {"effect": -0.011717043817043304, "value": 0.8125}, "16": {"effect": -0.03204098343849182, "value": -0.25}, "17": {"effect": -0.04137658327817917, "value": -1.0}, "18": {"effect": 0.013730050064623356, "value": 0.0}, "19": {"effect": 0.006378802936524153, "value": -0.3333333333333333}, "20": {"effect": 0.010352914221584797, "value": 0.0}, "21": {"effect": 0.0011696085566654801, "value": -0.509090909090909}, "22": {"effect": -0.07630323618650436, "value": -0.7142857142857143}, "23": {"effect": -0.00509627303108573, "value": -0.4195519348268847}, "24": {"effect": -0.019282972440123558, "value": -0.349794238683129}, "25": {"effect": -0.004283694550395012, "value": 0.5123966942148765}, "26": {"effect": -0.00924503430724144, "value": 0.6004184100418414}, "27": {"effect": -0.10505286604166031, "value": -0.693939393939394}, "28": {"effect": -0.014520121738314629, "value": -0.7231012658227847}, "29": {"effect": 0.002402727957814932, "value": 1.1992296918767495}, "30": {"effect": -0.0013284407323226333, "value": -0.15538552089464408}, "31": {"effect": 0.0018485105829313397, "value": 0.5874125874125875}, "32": {"effect": 0.0021122251637279987, "value": 0.9406699937815896}, "33": {"effect": -0.008610602468252182, "value": 0.9748427672955972}, "34": {"effect": -0.0026696238201111555, "value": -0.07913669064748367}, "35": {"effect": -0.0010550093138590455, "value": 0.11698113207547217}, "36": {"effect": -0.005809680558741093, "value": -0.25000000000004163}, "37": {"effect": -0.0013387654908001423, "value": 0.9406146179401986}, "38": {"effect": -0.006399137899279594, "value": 0.8182608695652196}, "39": {"effect": 0.000887785165105015, "value": 0.8160500260552331}, "40": {"effect": 0.003647431032732129, "value": -0.46153846153846156}, "41": {"effect": -0.09128551185131073, "value": -0.37064676616915454}}, "plot_cmap": "RdBu", "labelMar ...
#     document.getElementById('i4V4CNBTO0NCHB928XXN6')
#   );
# </script>

# %%
shap.summary_plot(shap_values, X_val_scaled_df)

# %% [markdown]
# # Model Stacking

# %%
from sklearn.ensemble import StackingClassifier
from xgboost import XGBClassifier

# %%
# logistic regression with best parameters
log_reg = LogisticRegression(C=10, penalty='l2', solver='saga', max_iter=100, random_state=42)

# XGBoost with best parameters
xgb_clf = XGBClassifier(
    colsample_bytree=0.7, 
    learning_rate=0.01, 
    max_depth=5, 
    n_estimators=300, 
    subsample=0.8, 
    random_state=42
)

# SVC with best parameters
svc_clf = SVC(C=10, gamma='scale', kernel='linear', probability=True, random_state=42)

# %%
# define the base learners and meta-model
estimators = [
    ('log_reg', log_reg),
    ('xgb_clf', xgb_clf),
    ('svc_clf', svc_clf)
]

# stacking classifier (meta-learner)
stacked_clf = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression(random_state=42),
    cv=5
)

# %%
# fit the stacked model on training data
stacked_clf.fit(X_train, y_train)
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
y_val_pred = stacked_clf.predict(X_val)

val_accuracy = accuracy_score(y_val, y_val_pred)
print(f'Validation Accuracy: {val_accuracy:.4f}')

print("Confusion Matrix:")
print(confusion_matrix(y_val, y_val_pred))

print("Classification Report:")
print(classification_report(y_val, y_val_pred))

# %%
y_test_pred = stacked_clf.predict(X_test)

test_accuracy = accuracy_score(y_test, y_test_pred)
print(f'Test Accuracy: {test_accuracy:.4f}')

print("Test Confusion Matrix:")
print(confusion_matrix(y_test, y_test_pred))

print("Test Classification Report:")
print(classification_report(y_test, y_test_pred))
